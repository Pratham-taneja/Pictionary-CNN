# %% [markdown]
# # 0. Data Importing from kaggle

# %%
import os
from tqdm.notebook import tqdm
for dirname, _, filenames in tqdm(os.walk('/kaggle/input')):
    for filename in filenames:
        os.path.join(dirname, filename)
#         print(os.path.join(dirname, filename))
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Limiting GPU usage

# %%
# limit memory to prevent data leak
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    
    del logical_gpus,gpus
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# # 1. Importing modules

# %%
import numpy as np
import pandas as pd
import json
import gc
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import os
train_files = glob("../input/quickdraw-doodle-recognition/train_simplified/*.csv")
testing = False
# calculating data size per category
rows = 200000

if testing:
    rows = 10000 # testing

rows = rows - (rows % 340)
cat_size = rows // 340
print(cat_size)
gc.collect()
# Out:
# 588
# 56

# %% [markdown]
# # 2. Data Importing and Image Preprocessing
# 1. Data Importing and Removing unwanted columns
# 2. converting data in text json to an image
# 3. normalizing the image size
# 4. normalizing the image pixels

# %%
from PIL import Image, ImageDraw
from dask import bag
def drawStrokes(matrixOfStrokes):
    image = Image.new("RGB", (256,256), color=255)
    image_draw = ImageDraw.Draw(image)
    for stroke in json.loads(matrixOfStrokes):
        for i in range(len(stroke[0])-1):
            image_draw.line([stroke[0][i], 
                             stroke[1][i],
                             stroke[0][i+1], 
                             stroke[1][i+1]],
                            fill=0, width=5)
    return np.array(image.resize((32,32)))/255.

# %%
from tqdm.notebook import tqdm
X = np.zeros((rows,32,32,3))
categories = pd.Series([None] * rows)
i = 0
for f in tqdm(train_files):
    for df in pd.read_csv(f, index_col="key_id", chunksize=1000, nrows=cat_size):
        df = df.drop(['countrycode','timestamp','recognized'],axis=1)
        imagebag = bag.from_sequence(df.drawing.values).map(drawStrokes)
        imagebag = np.array(imagebag.compute())
        categories[i:(i + imagebag.shape[0])] = df["word"].replace("\s+", "_", regex=True)
        X[i:(i + imagebag.shape[0])] = imagebag
        i += imagebag.shape[0]
# Out:
#   0%|          | 0/340 [00:00<?, ?it/s]

# %%
gc.collect()
# Out:
# 39

# %%
categories.value_counts()
# Out:
# traffic_light    588
# umbrella         588
# house            588
# trombone         588
# paper_clip       588
#                 ...
# rain             588
# rabbit           588
# lantern          588
# toaster          588
# fish             588
# Length: 340, dtype: int64

# %% [markdown]
# # 3. Train Test split

# %%
from sklearn.model_selection import train_test_split
Y = pd.get_dummies(categories)
tr_x,tst_x,tr_Y,tst_Y = train_test_split(X, Y, test_size=0.25,shuffle=True,stratify=Y)

# %%
itr = 0
for df in tr_Y:
    print(f"{df} : {tr_Y[df].value_counts()[1]}")
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 441
# The_Great_Wall_of_China : 441
# The_Mona_Lisa : 441
# airplane : 441
# alarm_clock : 441
# ambulance : 441

# %%
itr = 0
for df in tst_Y:
    try:
        print(f"{df} : {tst_Y[df].value_counts()[1]}")
    except:
        print(f"{df} : 0")
        
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 147
# The_Great_Wall_of_China : 147
# The_Mona_Lisa : 147
# airplane : 147
# alarm_clock : 147
# ambulance : 147

# %%
del X,categories
gc.collect()
# Out:
# 63

# %% [markdown]
# # 4. Creating Deep learning model
#
# - model choosen for problem statement is a CNN
# - additionally we also need to add an EarlyStopping to prevent overfitting and ModelCheckpoint to save the best model as callback
# - model uses categorical crossentropy to calculate loss and Adam as an optimizer

# %%
from keras.callbacks import ModelCheckpoint
# from tensorflow.keras.optimizers.legacy import Adam

filepath = 'my_best_model.h5'

checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor="val_accuracy", 
                             save_best_only=True,
                             mode='min')

# %%
from keras.callbacks import EarlyStopping
earlystop= EarlyStopping(monitor='val_accuracy', patience=6)

# %%
# callbacks = [checkpoint,earlystop]
callbacks = [checkpoint]

# %%
gc.collect()
# Out:
# 84

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import *
from tensorflow.keras import regularizers

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    
    model = Sequential()
    
    model.add(Conv2D(64, (3,3), activation = 'relu', padding = 'same',input_shape=(32,32,3)))
    model.add(Conv2D(64, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    # model.add(Dropout(0.25))
    model.add(BatchNormalization())
    
    model.add(Conv2D(128, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(128, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    # model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(256, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(256, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    # model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(512, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(512, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    # model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(1024, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(1024, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    # model.add(Dropout(0.25))
    model.add(BatchNormalization())
    model.add(Flatten())

    
    model.add(Dense(1024, activation='relu',kernel_regularizer=regularizers.l2(0.05)))
#     model.add(Dense(1024, activation='relu'))
#     model.add(Dropout(0.25))
    model.add(BatchNormalization())

#     model.add(Dense(512, activation='relu'))
    model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
#     model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Dense(340, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',
              optimizer= "adam",
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 16, 16, 64)       256
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 2, 2, 512)        2048
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 1024)        4719616
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 1024)        9438208
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 1024)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 1, 1, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  batch_normalization_5 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 340)               174420
#
# =================================================================
# Total params: 20,606,100
# Trainable params: 20,599,060
# Non-trainable params: 7,040
# _________________________________________________________________

# %%
gc.collect()
# Out:
# 192

# %% [markdown]
# # 6. Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def to_grayscale_then_rgb(image):
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.grayscale_to_rgb(image)
    return image

batch_size = 128
aug = ImageDataGenerator(
        rotation_range=20,
#         preprocessing_function=to_grayscale_then_rgb,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest")

test_aug = ImageDataGenerator(
        preprocessing_function=to_grayscale_then_rgb)

# %% [markdown]
# # 5. Training Deep learning model

# %% [markdown]
# RUN 1

# %%
if testing == True:
    history = model.fit(
        x=aug.flow(tr_x, tr_Y, batch_size=batch_size),
        validation_data=(tst_x,tst_Y),
        epochs=30,
        shuffle = True,
        callbacks=callbacks)
else:
    history = model.fit(
        x=aug.flow(tr_x, tr_Y, batch_size=batch_size,shuffle=True),
        validation_data=(tst_x,tst_Y),
        epochs=100,
        callbacks=callbacks)

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# Out:
# Epoch 1/100
# 1172/1172 [==============================] - 174s 126ms/step - loss: 6.8003 - accuracy: 0.0381 - val_loss: 5.8347 - val_accuracy: 0.0403
# Epoch 2/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 4.6961 - accuracy: 0.1098 - val_loss: 4.5882 - val_accuracy: 0.1250
# Epoch 3/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 4.1074 - accuracy: 0.1785 - val_loss: 4.9528 - val_accuracy: 0.0913
# Epoch 4/100
# 1172/1172 [==============================] - 151s 129ms/step - loss: 3.6907 - accuracy: 0.2371 - val_loss: 3.9925 - val_accuracy: 0.2085
# Epoch 5/100
# 1172/1172 [==============================] - 154s 131ms/step - loss: 3.3664 - accuracy: 0.2843 - val_loss: 10.1537 - val_accuracy: 0.0646
# Epoch 6/100
# 1172/1172 [==============================] - 150s 128ms/step - loss: 3.1350 - accuracy: 0.3174 - val_loss: 3.4187 - val_accuracy: 0.2627
# Epoch 7/100
# 1172/1172 [==============================] - 148s 126ms/step - loss: 2.9453 - accuracy: 0.3521 - val_loss: 4.9362 - val_accuracy: 0.1978
# Epoch 8/100
# 1172/1172 [==============================] - 150s 128ms/step - loss: 2.7953 - accuracy: 0.3808 - val_loss: 3.1927 - val_accuracy: 0.3076
# Epoch 9/100
# 1172/1172 [==============================] - 147s 126ms/step - loss: 2.6752 - accuracy: 0.4041 - val_loss: 2.4091 - val_accuracy: 0.4557
# Epoch 10/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 2.5919 - accuracy: 0.4222 - val_loss: 2.4092 - val_accuracy: 0.4582
# Epoch 11/100
# 1172/1172 [==============================] - 139s 119ms/step - loss: 2.5115 - accuracy: 0.4373 - val_loss: 2.8946 - val_accuracy: 0.3775
# Epoch 12/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 2.4423 - accuracy: 0.4519 - val_loss: 2.3106 - val_accuracy: 0.4812
# Epoch 13/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 2.3892 - accuracy: 0.4619 - val_loss: 2.3828 - val_accuracy: 0.4658
# Epoch 14/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 2.3407 - accuracy: 0.4724 - val_loss: 2.1255 - val_accuracy: 0.5270
# Epoch 15/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 2.2917 - accuracy: 0.4831 - val_loss: 2.1772 - val_accuracy: 0.5098
# Epoch 16/100
# 1172/1172 [==============================] - 145s 124ms/step - loss: 2.2513 - accuracy: 0.4918 - val_loss: 2.1695 - val_accuracy: 0.5266
# Epoch 17/100
# 1172/1172 [==============================] - 145s 123ms/step - loss: 2.2133 - accuracy: 0.4991 - val_loss: 2.6803 - val_accuracy: 0.4106
# Epoch 18/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 2.1754 - accuracy: 0.5056 - val_loss: 2.0850 - val_accuracy: 0.5331
# Epoch 19/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 2.1420 - accuracy: 0.5140 - val_loss: 2.0051 - val_accuracy: 0.5508
# Epoch 20/100
# 1172/1172 [==============================] - 147s 125ms/step - loss: 2.1121 - accuracy: 0.5187 - val_loss: 2.0822 - val_accuracy: 0.5349
# Epoch 21/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 2.0857 - accuracy: 0.5257 - val_loss: 2.3717 - val_accuracy: 0.4684
# Epoch 22/100
# 1172/1172 [==============================] - 147s 125ms/step - loss: 2.0596 - accuracy: 0.5299 - val_loss: 1.9211 - val_accuracy: 0.5716
# Epoch 23/100
# 1172/1172 [==============================] - 155s 132ms/step - loss: 2.0265 - accuracy: 0.5380 - val_loss: 1.9263 - val_accuracy: 0.5631
# Epoch 24/100
# 1172/1172 [==============================] - 151s 129ms/step - loss: 2.0029 - accuracy: 0.5415 - val_loss: 1.8813 - val_accuracy: 0.5734
# Epoch 25/100
# 1172/1172 [==============================] - 146s 124ms/step - loss: 1.9719 - accuracy: 0.5509 - val_loss: 2.0137 - val_accuracy: 0.5442
# Epoch 26/100
# 1172/1172 [==============================] - 145s 123ms/step - loss: 1.9466 - accuracy: 0.5539 - val_loss: 1.8158 - val_accuracy: 0.5915
# Epoch 27/100
# 1172/1172 [==============================] - 145s 124ms/step - loss: 1.9345 - accuracy: 0.5569 - val_loss: 1.7804 - val_accuracy: 0.6003
# Epoch 28/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 1.9051 - accuracy: 0.5615 - val_loss: 3.5640 - val_accuracy: 0.3250
# Epoch 29/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 1.8840 - accuracy: 0.5675 - val_loss: 1.8538 - val_accuracy: 0.5813
# Epoch 30/100
# 1172/1172 [==============================] - 148s 126ms/step - loss: 1.8700 - accuracy: 0.5700 - val_loss: 1.8339 - val_accuracy: 0.5912
# Epoch 31/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 1.8490 - accuracy: 0.5734 - val_loss: 1.8154 - val_accuracy: 0.5965
# Epoch 32/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 1.8278 - accuracy: 0.5776 - val_loss: 1.7939 - val_accuracy: 0.5984
# Epoch 33/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 1.8165 - accuracy: 0.5817 - val_loss: 1.8513 - val_accuracy: 0.5863
# Epoch 34/100
# 1172/1172 [==============================] - 148s 126ms/step - loss: 1.7922 - accuracy: 0.5858 - val_loss: 1.7994 - val_accuracy: 0.5992
# Epoch 35/100
# 1172/1172 [==============================] - 145s 124ms/step - loss: 1.7811 - accuracy: 0.5885 - val_loss: 2.1752 - val_accuracy: 0.5221
# Epoch 36/100
# 1172/1172 [==============================] - 154s 131ms/step - loss: 1.7549 - accuracy: 0.5929 - val_loss: 1.9167 - val_accuracy: 0.5774
# Epoch 37/100
# 1172/1172 [==============================] - 153s 131ms/step - loss: 1.7409 - accuracy: 0.5954 - val_loss: 1.8252 - val_accuracy: 0.5906
# Epoch 38/100
# 1172/1172 [==============================] - 145s 124ms/step - loss: 1.7334 - accuracy: 0.5977 - val_loss: 1.7834 - val_accuracy: 0.6053
# Epoch 39/100
# 1172/1172 [==============================] - 148s 126ms/step - loss: 1.7118 - accuracy: 0.6022 - val_loss: 1.8116 - val_accuracy: 0.5931
# Epoch 40/100
# 1172/1172 [==============================] - 155s 133ms/step - loss: 1.6998 - accuracy: 0.6046 - val_loss: 2.0358 - val_accuracy: 0.5536
# Epoch 41/100
# 1172/1172 [==============================] - 151s 129ms/step - loss: 1.6880 - accuracy: 0.6075 - val_loss: 1.7510 - val_accuracy: 0.6135
# Epoch 42/100
# 1172/1172 [==============================] - 156s 133ms/step - loss: 1.6723 - accuracy: 0.6110 - val_loss: 1.7288 - val_accuracy: 0.6151
# Epoch 43/100
# 1172/1172 [==============================] - 158s 135ms/step - loss: 1.6640 - accuracy: 0.6117 - val_loss: 1.8048 - val_accuracy: 0.5946
# Epoch 44/100
# 1172/1172 [==============================] - 160s 137ms/step - loss: 1.6390 - accuracy: 0.6156 - val_loss: 1.7729 - val_accuracy: 0.6070
# Epoch 45/100
# 1172/1172 [==============================] - 158s 135ms/step - loss: 1.6345 - accuracy: 0.6180 - val_loss: 1.8233 - val_accuracy: 0.6016
# Epoch 46/100
# 1172/1172 [==============================] - 154s 131ms/step - loss: 1.6215 - accuracy: 0.6199 - val_loss: 1.7798 - val_accuracy: 0.6060
# Epoch 47/100
# 1172/1172 [==============================] - 139s 118ms/step - loss: 1.6107 - accuracy: 0.6229 - val_loss: 1.7534 - val_accuracy: 0.6122
# Epoch 48/100
# 1172/1172 [==============================] - 139s 119ms/step - loss: 1.5965 - accuracy: 0.6251 - val_loss: 1.7698 - val_accuracy: 0.6035
# Epoch 49/100
# 1172/1172 [==============================] - 139s 119ms/step - loss: 1.5885 - accuracy: 0.6282 - val_loss: 1.7135 - val_accuracy: 0.6222
# Epoch 50/100
# 1172/1172 [==============================] - 139s 118ms/step - loss: 1.5726 - accuracy: 0.6306 - val_loss: 1.7829 - val_accuracy: 0.6042
# Epoch 51/100
# 1172/1172 [==============================] - 139s 119ms/step - loss: 1.5642 - accuracy: 0.6323 - val_loss: 1.9020 - val_accuracy: 0.5877
# Epoch 52/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 1.5509 - accuracy: 0.6350 - val_loss: 1.7355 - val_accuracy: 0.6190
# Epoch 53/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 1.5435 - accuracy: 0.6370 - val_loss: 1.7567 - val_accuracy: 0.6167
# Epoch 54/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.5289 - accuracy: 0.6388 - val_loss: 1.7386 - val_accuracy: 0.6196
# Epoch 55/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.5229 - accuracy: 0.6418 - val_loss: 1.8403 - val_accuracy: 0.6002
# Epoch 56/100
# 1172/1172 [==============================] - 139s 119ms/step - loss: 1.5122 - accuracy: 0.6427 - val_loss: 1.7998 - val_accuracy: 0.6027
# Epoch 57/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 1.5069 - accuracy: 0.6459 - val_loss: 1.7077 - val_accuracy: 0.6256
# Epoch 58/100
# 1172/1172 [==============================] - 145s 123ms/step - loss: 1.4924 - accuracy: 0.6464 - val_loss: 1.7484 - val_accuracy: 0.6192
# Epoch 59/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.4812 - accuracy: 0.6494 - val_loss: 1.7468 - val_accuracy: 0.6179
# Epoch 60/100
# 1172/1172 [==============================] - 141s 121ms/step - loss: 1.4725 - accuracy: 0.6522 - val_loss: 1.7999 - val_accuracy: 0.6107
# Epoch 61/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.4659 - accuracy: 0.6522 - val_loss: 1.7561 - val_accuracy: 0.6215
# Epoch 62/100
# 1172/1172 [==============================] - 139s 118ms/step - loss: 1.4571 - accuracy: 0.6554 - val_loss: 1.7524 - val_accuracy: 0.6223
# Epoch 63/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.4496 - accuracy: 0.6567 - val_loss: 1.6969 - val_accuracy: 0.6314
# Epoch 64/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.4347 - accuracy: 0.6592 - val_loss: 1.7194 - val_accuracy: 0.6282
# Epoch 65/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 1.4248 - accuracy: 0.6607 - val_loss: 1.8098 - val_accuracy: 0.6131
# Epoch 66/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 1.4189 - accuracy: 0.6614 - val_loss: 1.8135 - val_accuracy: 0.6093
# Epoch 67/100
# 1172/1172 [==============================] - 145s 123ms/step - loss: 1.4150 - accuracy: 0.6637 - val_loss: 1.7323 - val_accuracy: 0.6248
# Epoch 68/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 1.4033 - accuracy: 0.6670 - val_loss: 1.7506 - val_accuracy: 0.6222
# Epoch 69/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.3918 - accuracy: 0.6693 - val_loss: 1.8294 - val_accuracy: 0.6174
# Epoch 70/100
# 1172/1172 [==============================] - 140s 120ms/step - loss: 1.3839 - accuracy: 0.6707 - val_loss: 1.7801 - val_accuracy: 0.6232
# Epoch 71/100
# 1172/1172 [==============================] - 140s 120ms/step - loss: 1.3740 - accuracy: 0.6727 - val_loss: 1.7792 - val_accuracy: 0.6184
# Epoch 72/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 1.3737 - accuracy: 0.6719 - val_loss: 1.8623 - val_accuracy: 0.6037
# Epoch 73/100
# 1172/1172 [==============================] - 140s 120ms/step - loss: 1.3572 - accuracy: 0.6745 - val_loss: 1.8172 - val_accuracy: 0.6060
# Epoch 74/100
# 1172/1172 [==============================] - 145s 124ms/step - loss: 1.3475 - accuracy: 0.6772 - val_loss: 1.7861 - val_accuracy: 0.6239
# Epoch 75/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.3449 - accuracy: 0.6780 - val_loss: 1.7568 - val_accuracy: 0.6266
# Epoch 76/100
# 1172/1172 [==============================] - 141s 121ms/step - loss: 1.3391 - accuracy: 0.6786 - val_loss: 1.7773 - val_accuracy: 0.6248
# Epoch 77/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.3261 - accuracy: 0.6824 - val_loss: 1.7546 - val_accuracy: 0.6275
# Epoch 78/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.3229 - accuracy: 0.6832 - val_loss: 1.8536 - val_accuracy: 0.6115
# Epoch 79/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 1.3133 - accuracy: 0.6856 - val_loss: 1.8440 - val_accuracy: 0.6070
# Epoch 80/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.3036 - accuracy: 0.6872 - val_loss: 1.7718 - val_accuracy: 0.6305
# Epoch 81/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.2986 - accuracy: 0.6881 - val_loss: 1.7979 - val_accuracy: 0.6221
# Epoch 82/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.2994 - accuracy: 0.6879 - val_loss: 1.7742 - val_accuracy: 0.6266
# Epoch 83/100
# 1172/1172 [==============================] - 140s 120ms/step - loss: 1.2851 - accuracy: 0.6910 - val_loss: 1.7925 - val_accuracy: 0.6247
# Epoch 84/100
# 1172/1172 [==============================] - 140s 120ms/step - loss: 1.2704 - accuracy: 0.6943 - val_loss: 1.8017 - val_accuracy: 0.6240
# Epoch 85/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.2717 - accuracy: 0.6931 - val_loss: 1.7913 - val_accuracy: 0.6245
# Epoch 86/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.2638 - accuracy: 0.6948 - val_loss: 1.8201 - val_accuracy: 0.6284
# Epoch 87/100
# 1172/1172 [==============================] - 143s 122ms/step - loss: 1.2584 - accuracy: 0.6960 - val_loss: 1.8085 - val_accuracy: 0.6242
# Epoch 88/100
# 1172/1172 [==============================] - 142s 121ms/step - loss: 1.2507 - accuracy: 0.6976 - val_loss: 1.8687 - val_accuracy: 0.6158
# Epoch 89/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.2505 - accuracy: 0.6986 - val_loss: 1.8192 - val_accuracy: 0.6168
# Epoch 90/100
# 1172/1172 [==============================] - 144s 123ms/step - loss: 1.2363 - accuracy: 0.7008 - val_loss: 1.8236 - val_accuracy: 0.6202
# Epoch 91/100
# 1172/1172 [==============================] - 141s 120ms/step - loss: 1.2273 - accuracy: 0.7040 - val_loss: 1.8560 - val_accuracy: 0.6136
# Epoch 92/100
# 1172/1172 [==============================] - 137s 117ms/step - loss: 1.2195 - accuracy: 0.7051 - val_loss: 1.8701 - val_accuracy: 0.6219
# Epoch 93/100
# 1172/1172 [==============================] - 140s 119ms/step - loss: 1.2253 - accuracy: 0.7030 - val_loss: 1.8930 - val_accuracy: 0.6040
# Epoch 94/100
# 1172/1172 [==============================] - 136s 116ms/step - loss: 1.2099 - accuracy: 0.7070 - val_loss: 1.9061 - val_accuracy: 0.6013
# Epoch 95/100
# 1172/1172 [==============================] - 138s 117ms/step - loss: 1.2090 - accuracy: 0.7075 - val_loss: 1.8888 - val_accuracy: 0.6201
# Epoch 96/100
# 1172/1172 [==============================] - 137s 117ms/step - loss: 1.1999 - accuracy: 0.7084 - val_loss: 1.9493 - val_accuracy: 0.6082
# Epoch 97/100
# 1172/1172 [==============================] - 138s 118ms/step - loss: 1.1897 - accuracy: 0.7117 - val_loss: 1.9269 - val_accuracy: 0.6138
# Epoch 98/100
# 1172/1172 [==============================] - 137s 117ms/step - loss: 1.1838 - accuracy: 0.7135 - val_loss: 2.0985 - val_accuracy: 0.5806
# Epoch 99/100
# 1172/1172 [==============================] - 138s 118ms/step - loss: 1.1777 - accuracy: 0.7155 - val_loss: 2.0287 - val_accuracy: 0.5822
# Epoch 100/100
# 1172/1172 [==============================] - 139s 118ms/step - loss: 1.1798 - accuracy: 0.7139 - val_loss: 1.8791 - val_accuracy: 0.6126
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
gc.collect()
# Out:
# 106267

# %% [markdown]
# # 6. Testing the model

# %%
del model
gc.collect()
# Out:
# 21

# %% [markdown]
# ## Loading saved model

# %%
from tensorflow.keras.models import load_model
model = load_model("my_best_model.h5")

# %% [markdown]
# ## Importing testing data

# %%
test = pd.read_csv('../input/quickdraw-doodle-recognition/test_simplified.csv', index_col="key_id" ,nrows=100)
ids = test.index
imagebag = bag.from_sequence(test.drawing.values).map(drawStrokes)
test_simplified = np.array(imagebag.compute())
test_simplified = test_simplified.reshape(len(test_simplified), 32, 32, 3)

# %%
del imagebag
gc.collect()
# Out:
# 21

# %% [markdown]
# ## Make predictions

# %%
prediction = model.predict(test_simplified)
indexOfBigProbability = (-prediction).argsort()[:,:4]
# Out:
# 4/4 [==============================] - 1s 127ms/step

# %%
gc.collect()
# Out:
# 721

# %% [markdown]
# ## Plotting the predictions

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import ast
import warnings
warnings.filterwarnings('ignore')

raw_images = [ast.literal_eval(lst) for lst in test.loc[test.iloc[:40].index, 'drawing'].values]

j=0

for index, raw_drawing in enumerate(raw_images):
    plt.figure(figsize=(3,3));
    for x,y in raw_drawing:
        title_obj=plt.title(Y.columns[indexOfBigProbability][j][0]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][1]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][2]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][3], fontsize=22)
        plt.subplot(1, 1, 1);
        plt.plot(x,y);
        plt.axis('off');
    plt.gca().invert_yaxis();
    j+=1;
